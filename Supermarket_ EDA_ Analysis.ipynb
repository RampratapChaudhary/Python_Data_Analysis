# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
os.chdir(r"C:\Users\champ\Desktop\data sc\stats & SQL\ML\EDA PROJECT")

# %%
data=pd.read_csv("supermarket_sales - Sheet1.csv",parse_dates=['Date'])

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Display random 5 rows.

# %%
data.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender        Product line  \
# 57   635-40-6220      A     Yangon        Normal    Male   Health and beauty
# 687  648-83-1321      A     Yangon        Member    Male  Home and lifestyle
# 396  316-01-3952      A     Yangon        Normal  Female  Food and beverages
# 414  472-15-9636      A     Yangon        Normal    Male  Home and lifestyle
# 711  728-88-7867      C  Naypyitaw        Member  Female  Home and lifestyle
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time  Payment  \
# 57        89.60         8  35.8400  752.6400 2019-02-07  11:28  Ewallet
# 687       63.56        10  31.7800  667.3800 2019-01-16  17:59     Cash
# 396       54.27         5  13.5675  284.9175 2019-03-13  14:16  Ewallet
# 414       50.93         8  20.3720  427.8120 2019-03-22  19:36  Ewallet
# 711       75.53         4  15.1060  317.2260 2019-03-19  15:52  Ewallet
#
#        cogs  gross margin percentage  gross income  Rating
# 57   716.80                 4.761905       35.8400     6.6
# 687  635.60                 4.761905       31.7800     4.3
# 396  271.35                 4.761905       13.5675     4.6
# 414  407.44                 4.761905       20.3720     9.2
# 711  302.12                 4.761905       15.1060     8.3

# %%
data.shape
# Out:
# (1000, 17)

# %% [markdown]
# #### Check for Null Values in the Dataset

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(8)
# memory usage: 132.9+ KB

# %% [markdown]
# #### Get overall Statistics about the dataset

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# 25%               4.761905e+00      5.924875     5.50000
# 50%               4.761905e+00     12.088000     7.00000
# 75%               4.761905e+00     22.445250     8.50000
# max               4.761905e+00     49.650000    10.00000

# %%
cat=[]
num=[]
for column in data.columns:
    if data[column].nunique()>10:
        num.append(column)
    else:
         cat.append(column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# #### Find aggregate Sales among branches.(Categorical Column)

# %%
sns.countplot(data['Branch'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %%
data['Branch'].value_counts().plot(kind='pie',autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='Branch'>

# %%
data['Branch'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Find the most popular payment method used by customers (Categorical Column)

# %%
data['Payment'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Find the distribution of customer Ratings.(Numerical Column)

# %%
sns.distplot(data['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
data['Rating'].skew()
# Out:
# 0.00900964876573073

# %% [markdown]
# #### Find the Distribution of cost of goods sold (Numerical Column)

# %%
sns.distplot(data['cogs'])
# Out:
# <AxesSubplot:xlabel='cogs', ylabel='Density'>

# %%
data['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
sns.boxplot(data['cogs'])
# Out:
# <AxesSubplot:xlabel='cogs'>

# %% [markdown]
# ## Bivariate Analysis/ Multivariate Analysis

# %% [markdown]
# #### Does the cost of Goods Sold affect the ratings that the customers provide? (Numerical-Numerical)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
sns.scatterplot(data['cogs'],data['Rating'])
# Out:
# <AxesSubplot:xlabel='cogs', ylabel='Rating'>

# %% [markdown]
# ##### from scatter plot, we can see no relationship between cogs and rating

# %% [markdown]
# #### Does Gross Income affect the ratings that the customers provide? (Numerical-Numerical)

# %%
sns.scatterplot(data['gross income'], data['Rating'])
# Out:
# <AxesSubplot:xlabel='gross income', ylabel='Rating'>

# %% [markdown]
# #### Find the most Profitable Branch as per Gross Income.(Numerical-Categorical)

# %%
sns.barplot(data['Branch'],data['gross income'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(data['Branch'],data['gross income'],hue=data['City'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='gross income'>

# %% [markdown]
# #### Is there any relationship between Gender and gross Income?(Numerical-Categorical)

# %%
sns.boxplot(data['Gender'],data['gross income'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(data['Gender'],data['gross income'],hue=data['Customer type'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='gross income'>

# %% [markdown]
# #### Find the product Line that generates the most income.(Numerical-Categorical)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.barplot(data['Product line'],data['gross income'])
plt.xticks(rotation=60)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Find the highest unit price in the product line. (numerical-Categorical)

# %%
sns.barplot(data['Product line'],data['Unit price'])
plt.xticks(rotation=60)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Find different payment methods Used by Customers Citywise. (Categorical-Categorical)

# %%
pd.crosstab(data['City'],data['Payment'])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(data['City'],data['Payment']))
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='City'>

# %% [markdown]
# #### Which product line is purchased in the highest quantity?

# %%
(data.groupby('Product line').sum()['Quantity']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Product line'>

# %% [markdown]
# #### Display daily sales by day of the week

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
dw_mapping={0:'Mon',1:'Tue',2:'Wed',3:'Thur',4:'Fri',5:'Sat',6:'Sun'}

# %%
data['day_of_week']=data['Date'].dt.dayofweek.map(dw_mapping)

# %%
data.head(1)
# Out:
#     Invoice ID Branch    City Customer type  Gender       Product line  \
# 0  750-67-8428      A  Yangon        Member  Female  Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time  Payment    cogs  \
# 0       74.69         7  26.1415  548.9715 2019-01-05  13:08  Ewallet  522.83
#
#    gross margin percentage  gross income  Rating day_of_week
# 0                 4.761905       26.1415     9.1         Sat

# %%
data['day_of_week'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What will be the highest months for Sales

# %%
month_mapping={1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}

# %%
data.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
#
#   day_of_week
# 0         Sat
# 1         Fri
# 2         Sun

# %%
data['Month']=data['Date'].dt.month.map(month_mapping)

# %%
data.head(12)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      B   Mandalay        Member    Male
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 0        Health and beauty       74.69         7  26.1415  548.9715
# 1   Electronic accessories       15.28         5   3.8200   80.2200
# 2       Home and lifestyle       46.33         7  16.2155  340.5255
# 3        Health and beauty       58.22         8  23.2880  489.0480
# 4        Sports and travel       86.31         7  30.2085  634.3785
# 5   Electronic accessories       85.39         7  29.8865  627.6165
# 6   Electronic accessories       68.84         6  20.6520  433.6920
# 7       Home and lifestyle       73.56        10  36.7800  772.3800
# 8        Health and beauty       36.26         2   3.6260   76.1460
# 9       Food and beverages       54.84         3   8.2260  172.7460
# 10     Fashion accessories       14.48         4   2.8960   60.8160
# 11  Electronic accessories       25.51         4   5.1020  107.1420
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  2019-01-05  13:08      Ewallet  522.83                 4.761905
# 1  2019-03-08  10:29         Cash   76.40                 4.761905
# 2  2019-03-03  13:23  Credit card  324.31                 4.761905
# 3  2019-01-27  20:33      Ewallet  465.76                 4.761905
# 4  2019-02-08  10:37      Ewallet  604.17                 4.761905
# 5  2019-03-25  18:30      Ewallet  597.73                 4.761905
# 6  2019-02-25  14:36      Ewallet  413.04                 4.761905
# 7  2019-02-24  11:38      Ewallet  735.60                 4.761905
# 8  2019-01-10  17:15  Credit card   72.52                 4.761905
# 9  2019-02-20  13:27  Credit card  164.52                 4.761905
# 10 2019-02-06  18:07      Ewallet   57.92                 4.761905
# 11 2019-03-09  17:03         Cash  102.04                 4.761905
#
#     gross income  Rating day_of_week Month
# 0        26.1415     9.1         Sat   Jan
# 1         3.8200     9.6         Fri   Mar
# 2        16.2155     7.4         Sun   Mar
# 3        23.2880     8.4         Sun   Jan
# 4        30.2085     5.3         Fri   Feb
# 5        29.8865     4.1         Mon   Mar
# 6        20.6520     5.8         Mon   Feb
# 7        36.7800     8.0         Sun   Feb
# 8         3.6260     7.2        Thur   Jan
# 9         8.2260     5.9         Wed   Feb
# 10        2.8960     4.5         Wed   Feb
# 11        5.1020     6.8         Sat   Mar

# %%
data['Month'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
